# %% [markdown]
# ## 순환신경망 모델

# %%
import requests
import csv
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from fbprophet import Prophet
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
# %matplotlib inline
model_path = './'
target_col='price'

# %%
data = pd.read_csv("D:/학교/4학년/1학기/캡스톤디자인/농산물 유통정보/대파/data.csv")

# %%
data.index = data['date']
del data['date']
del data['Unnamed: 0']
data.head(3)
# Out:
#             평균기온(°C)  최저기온(°C)  최고기온(°C)          생산량  price
# date
# 2010-01-04      -0.3      -3.9       4.8  610578000.0   2232
# 2010-01-05      -5.1      -5.9      -1.9  610578000.0   2216
# 2010-01-06      -4.9      -6.1      -3.7  610578000.0   2267

# %%
def train_test_split(df, test_size=0.2):
    split_row = len(df) - int(test_size * len(df))
    train_data = df.iloc[:split_row]
    test_data = df.iloc[split_row:]
    return train_data, test_data

# %%
train, test = train_test_split(data, test_size=0.2)

# %%
def line_plot(line1, line2, label1=None, label2=None, title='', lw=2):
    fig, ax = plt.subplots(1, figsize=(13, 7))
    ax.plot(line1, label=label1, linewidth=lw)
    ax.plot(line2, label=label2, linewidth=lw)
    ax.set_ylabel('price [CAD]', fontsize=14)
    ax.set_title(title, fontsize=16)
    ax.legend(loc='best', fontsize=16);

# %%
line_plot(train[target_col], test[target_col], 'training', 'test', title='')

# %%
#정규화
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scale_cols = ['평균기온(°C)','최저기온(°C)','최고기온(°C)','생산량','price']
learn_data_scaled = scaler.fit_transform(data[scale_cols])

learn_data_scaled = pd.DataFrame(learn_data_scaled, index = data.index)
learn_data_scaled.columns = scale_cols

# %%
train, test = train_test_split(learn_data_scaled, test_size=0.2)

# %%
def make_dataset(data, label, window_size=30):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

# %%
feature_cols = ['평균기온(°C)','최저기온(°C)','최고기온(°C)','생산량']
label_cols = ['price']

train_feature = train[feature_cols]
train_label = train[label_cols]

# train dataset
train_feature, train_label = make_dataset(train_feature, train_label, 30)

test_feature = test[feature_cols]
test_label = test[label_cols]

# test dataset (실제 예측 해볼 데이터)
test_feature, test_label = make_dataset(test_feature, test_label, 30)

# train, validation set 생성
from sklearn.model_selection import train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2)

# %%
model = Sequential()
model.add(LSTM(16, 
               input_shape=(train_feature.shape[1], train_feature.shape[2]), 
               activation='relu', 
               return_sequences=False))
model.add(Dense(16,activation='relu'))
model.add(Dense(1))

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
early_stop = EarlyStopping(monitor='val_loss', patience=5)
filename = os.path.join(model_path, 'tmp_checkpoint.h5')
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

history = model.fit(x_train, y_train, 
                    epochs=100, 
                    batch_size=1,
                    shuffle=False,
                    validation_data=(x_valid, y_valid), 
                    callbacks=[early_stop, checkpoint])
# Out:
# Epoch 1/100
# 1485/1489 [============================>.] - ETA: 0s - loss: 0.0238
# Epoch 00001: val_loss improved from inf to 0.02025, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 4ms/step - loss: 0.0238 - val_loss: 0.0203
# Epoch 2/100
# 1474/1489 [============================>.] - ETA: 0s - loss: 0.0207
# Epoch 00002: val_loss improved from 0.02025 to 0.01899, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0206 - val_loss: 0.0190
# Epoch 3/100
# 1480/1489 [============================>.] - ETA: 0s - loss: 0.0197
# Epoch 00003: val_loss improved from 0.01899 to 0.01864, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0197 - val_loss: 0.0186
# Epoch 4/100
# 1489/1489 [==============================] - ETA: 0s - loss: 0.0192
# Epoch 00004: val_loss improved from 0.01864 to 0.01786, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0192 - val_loss: 0.0179
# Epoch 5/100
# 1475/1489 [============================>.] - ETA: 0s - loss: 0.0191
# Epoch 00005: val_loss improved from 0.01786 to 0.01775, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0190 - val_loss: 0.0178
# Epoch 6/100
# 1483/1489 [============================>.] - ETA: 0s - loss: 0.0175
# Epoch 00006: val_loss improved from 0.01775 to 0.01645, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0175 - val_loss: 0.0164
# Epoch 7/100
# 1487/1489 [============================>.] - ETA: 0s - loss: 0.0170
# Epoch 00007: val_loss improved from 0.01645 to 0.01555, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0170 - val_loss: 0.0156
# Epoch 8/100
# 1476/1489 [============================>.] - ETA: 0s - loss: 0.0166
# Epoch 00008: val_loss improved from 0.01555 to 0.01524, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0166 - val_loss: 0.0152
# Epoch 9/100
# 1487/1489 [============================>.] - ETA: 0s - loss: 0.0157
# Epoch 00009: val_loss improved from 0.01524 to 0.01466, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0157 - val_loss: 0.0147
# Epoch 10/100
# 1474/1489 [============================>.] - ETA: 0s - loss: 0.0154
# Epoch 00010: val_loss improved from 0.01466 to 0.01401, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0153 - val_loss: 0.0140
# Epoch 11/100
# 1483/1489 [============================>.] - ETA: 0s - loss: 0.0162
# Epoch 00011: val_loss did not improve from 0.01401
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0162 - val_loss: 0.0144
# Epoch 12/100
# 1476/1489 [============================>.] - ETA: 0s - loss: 0.0147
# Epoch 00012: val_loss improved from 0.01401 to 0.01344, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0146 - val_loss: 0.0134
# Epoch 13/100
# 1488/1489 [============================>.] - ETA: 0s - loss: 0.0140
# Epoch 00013: val_loss improved from 0.01344 to 0.01328, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0140 - val_loss: 0.0133
# Epoch 14/100
# 1481/1489 [============================>.] - ETA: 0s - loss: 0.0136
# Epoch 00014: val_loss did not improve from 0.01328
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0136 - val_loss: 0.0162
# Epoch 15/100
# 1479/1489 [============================>.] - ETA: 0s - loss: 0.0131
# Epoch 00015: val_loss improved from 0.01328 to 0.01296, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0130 - val_loss: 0.0130
# Epoch 16/100
# 1476/1489 [============================>.] - ETA: 0s - loss: 0.0128
# Epoch 00016: val_loss did not improve from 0.01296
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0128 - val_loss: 0.0135
# Epoch 17/100
# 1478/1489 [============================>.] - ETA: 0s - loss: 0.0128
# Epoch 00017: val_loss improved from 0.01296 to 0.01291, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0128 - val_loss: 0.0129
# Epoch 18/100
# 1479/1489 [============================>.] - ETA: 0s - loss: 0.0124
# Epoch 00018: val_loss improved from 0.01291 to 0.01283, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0124 - val_loss: 0.0128
# Epoch 19/100
# 1486/1489 [============================>.] - ETA: 0s - loss: 0.0120
# Epoch 00019: val_loss improved from 0.01283 to 0.01179, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0120 - val_loss: 0.0118
# Epoch 20/100
# 1484/1489 [============================>.] - ETA: 0s - loss: 0.0116
# Epoch 00020: val_loss did not improve from 0.01179
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0116 - val_loss: 0.0122
# Epoch 21/100
# 1475/1489 [============================>.] - ETA: 0s - loss: 0.0117
# Epoch 00021: val_loss improved from 0.01179 to 0.01178, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0116 - val_loss: 0.0118
# Epoch 22/100
# 1483/1489 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 00022: val_loss did not improve from 0.01178
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0112 - val_loss: 0.0119
# Epoch 23/100
# 1479/1489 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 00023: val_loss did not improve from 0.01178
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0112 - val_loss: 0.0130
# Epoch 24/100
# 1486/1489 [============================>.] - ETA: 0s - loss: 0.0110
# Epoch 00024: val_loss improved from 0.01178 to 0.01166, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0110 - val_loss: 0.0117
# Epoch 25/100
# 1476/1489 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 00025: val_loss improved from 0.01166 to 0.01117, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 26/100
# 1475/1489 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 00026: val_loss improved from 0.01117 to 0.01018, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0108 - val_loss: 0.0102
# Epoch 27/100
# 1478/1489 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00027: val_loss did not improve from 0.01018
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0106 - val_loss: 0.0109
# Epoch 28/100
# 1482/1489 [============================>.] - ETA: 0s - loss: 0.0106
# Epoch 00028: val_loss did not improve from 0.01018
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0106 - val_loss: 0.0102
# Epoch 29/100
# 1478/1489 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 00029: val_loss improved from 0.01018 to 0.00964, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0107 - val_loss: 0.0096
# Epoch 30/100
# 1479/1489 [============================>.] - ETA: 0s - loss: 0.0106
# Epoch 00030: val_loss did not improve from 0.00964
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0105 - val_loss: 0.0100
# Epoch 31/100
# 1477/1489 [============================>.] - ETA: 0s - loss: 0.0104
# Epoch 00031: val_loss did not improve from 0.00964
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0103 - val_loss: 0.0100
# Epoch 32/100
# 1481/1489 [============================>.] - ETA: 0s - loss: 0.0103
# Epoch 00032: val_loss improved from 0.00964 to 0.00959, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0103 - val_loss: 0.0096
# Epoch 33/100
# 1476/1489 [============================>.] - ETA: 0s - loss: 0.0103
# Epoch 00033: val_loss improved from 0.00959 to 0.00925, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0102 - val_loss: 0.0092
# Epoch 34/100
# 1482/1489 [============================>.] - ETA: 0s - loss: 0.0102
# Epoch 00034: val_loss did not improve from 0.00925
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0101 - val_loss: 0.0094
# Epoch 35/100
# 1489/1489 [==============================] - ETA: 0s - loss: 0.0101
# Epoch 00035: val_loss improved from 0.00925 to 0.00914, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0101 - val_loss: 0.0091
# Epoch 36/100
# 1474/1489 [============================>.] - ETA: 0s - loss: 0.0101
# Epoch 00036: val_loss did not improve from 0.00914
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0101 - val_loss: 0.0093
# Epoch 37/100
# 1472/1489 [============================>.] - ETA: 0s - loss: 0.0101
# Epoch 00037: val_loss improved from 0.00914 to 0.00891, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0100 - val_loss: 0.0089
# Epoch 38/100
# 1478/1489 [============================>.] - ETA: 0s - loss: 0.0099
# Epoch 00038: val_loss improved from 0.00891 to 0.00877, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0098 - val_loss: 0.0088
# Epoch 39/100
# 1473/1489 [============================>.] - ETA: 0s - loss: 0.0099
# Epoch 00039: val_loss improved from 0.00877 to 0.00855, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0098 - val_loss: 0.0086
# Epoch 40/100
# 1486/1489 [============================>.] - ETA: 0s - loss: 0.0096
# Epoch 00040: val_loss improved from 0.00855 to 0.00839, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0096 - val_loss: 0.0084
# Epoch 41/100
# 1489/1489 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 00041: val_loss improved from 0.00839 to 0.00837, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0095 - val_loss: 0.0084
# Epoch 42/100
# 1488/1489 [============================>.] - ETA: 0s - loss: 0.0093
# Epoch 00042: val_loss improved from 0.00837 to 0.00819, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0093 - val_loss: 0.0082
# Epoch 43/100
# 1483/1489 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 00043: val_loss did not improve from 0.00819
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0094 - val_loss: 0.0088
# Epoch 44/100
# 1486/1489 [============================>.] - ETA: 0s - loss: 0.0092
# Epoch 00044: val_loss improved from 0.00819 to 0.00810, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0092 - val_loss: 0.0081
# Epoch 45/100
# 1488/1489 [============================>.] - ETA: 0s - loss: 0.0092
# Epoch 00045: val_loss improved from 0.00810 to 0.00806, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0092 - val_loss: 0.0081
# Epoch 46/100
# 1486/1489 [============================>.] - ETA: 0s - loss: 0.0090
# Epoch 00046: val_loss improved from 0.00806 to 0.00789, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0090 - val_loss: 0.0079
# Epoch 47/100
# 1478/1489 [============================>.] - ETA: 0s - loss: 0.0090
# Epoch 00047: val_loss did not improve from 0.00789
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0089 - val_loss: 0.0080
# Epoch 48/100
# 1475/1489 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 00048: val_loss improved from 0.00789 to 0.00771, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0088 - val_loss: 0.0077
# Epoch 49/100
# 1478/1489 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 00049: val_loss did not improve from 0.00771
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0088 - val_loss: 0.0080
# Epoch 50/100
# 1483/1489 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 00050: val_loss improved from 0.00771 to 0.00765, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0089 - val_loss: 0.0076
# Epoch 51/100
# 1488/1489 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 00051: val_loss did not improve from 0.00765
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0086 - val_loss: 0.0077
# Epoch 52/100
# 1487/1489 [============================>.] - ETA: 0s - loss: 0.0085
# Epoch 00052: val_loss did not improve from 0.00765
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0085 - val_loss: 0.0080
# Epoch 53/100
# 1489/1489 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 00053: val_loss improved from 0.00765 to 0.00764, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0083 - val_loss: 0.0076
# Epoch 54/100
# 1478/1489 [============================>.] - ETA: 0s - loss: 0.0080
# Epoch 00054: val_loss improved from 0.00764 to 0.00726, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0079 - val_loss: 0.0073
# Epoch 55/100
# 1476/1489 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 00055: val_loss improved from 0.00726 to 0.00699, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0077 - val_loss: 0.0070
# Epoch 56/100
# 1478/1489 [============================>.] - ETA: 0s - loss: 0.0077
# Epoch 00056: val_loss did not improve from 0.00699
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0077 - val_loss: 0.0071
# Epoch 57/100
# 1481/1489 [============================>.] - ETA: 0s - loss: 0.0077
# Epoch 00057: val_loss improved from 0.00699 to 0.00689, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0077 - val_loss: 0.0069
# Epoch 58/100
# 1488/1489 [============================>.] - ETA: 0s - loss: 0.0075
# Epoch 00058: val_loss did not improve from 0.00689
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0075 - val_loss: 0.0083
# Epoch 59/100
# 1475/1489 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 00059: val_loss improved from 0.00689 to 0.00668, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0075 - val_loss: 0.0067
# Epoch 60/100
# 1477/1489 [============================>.] - ETA: 0s - loss: 0.0075
# Epoch 00060: val_loss did not improve from 0.00668
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0075 - val_loss: 0.0069
# Epoch 61/100
# 1487/1489 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 00061: val_loss improved from 0.00668 to 0.00650, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0072 - val_loss: 0.0065
# Epoch 62/100
# 1489/1489 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 00062: val_loss improved from 0.00650 to 0.00649, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0073 - val_loss: 0.0065
# Epoch 63/100
# 1473/1489 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 00063: val_loss improved from 0.00649 to 0.00628, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0072 - val_loss: 0.0063
# Epoch 64/100
# 1475/1489 [============================>.] - ETA: 0s - loss: 0.0073
# Epoch 00064: val_loss did not improve from 0.00628
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0072 - val_loss: 0.0063
# Epoch 65/100
# 1489/1489 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 00065: val_loss improved from 0.00628 to 0.00610, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0072 - val_loss: 0.0061
# Epoch 66/100
# 1479/1489 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 00066: val_loss improved from 0.00610 to 0.00605, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0072 - val_loss: 0.0061
# Epoch 67/100
# 1481/1489 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 00067: val_loss did not improve from 0.00605
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0070 - val_loss: 0.0063
# Epoch 68/100
# 1485/1489 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 00068: val_loss did not improve from 0.00605
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0071 - val_loss: 0.0061
# Epoch 69/100
# 1487/1489 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 00069: val_loss improved from 0.00605 to 0.00604, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0070 - val_loss: 0.0060
# Epoch 70/100
# 1483/1489 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 00070: val_loss improved from 0.00604 to 0.00578, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0070 - val_loss: 0.0058
# Epoch 71/100
# 1487/1489 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 00071: val_loss did not improve from 0.00578
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 72/100
# 1489/1489 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 00072: val_loss improved from 0.00578 to 0.00577, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0069 - val_loss: 0.0058
# Epoch 73/100
# 1483/1489 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 00073: val_loss did not improve from 0.00577
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0068 - val_loss: 0.0058
# Epoch 74/100
# 1472/1489 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 00074: val_loss improved from 0.00577 to 0.00555, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0068 - val_loss: 0.0055
# Epoch 75/100
# 1472/1489 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 00075: val_loss improved from 0.00555 to 0.00552, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0069 - val_loss: 0.0055
# Epoch 76/100
# 1488/1489 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 00076: val_loss improved from 0.00552 to 0.00549, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0066 - val_loss: 0.0055
# Epoch 77/100
# 1488/1489 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 00077: val_loss improved from 0.00549 to 0.00543, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0067 - val_loss: 0.0054
# Epoch 78/100
# 1487/1489 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 00078: val_loss improved from 0.00543 to 0.00531, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0067 - val_loss: 0.0053
# Epoch 79/100
# 1474/1489 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 00079: val_loss improved from 0.00531 to 0.00526, saving model to .\tmp_checkpoint.h5
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0065 - val_loss: 0.0053
# Epoch 80/100
# 1472/1489 [============================>.] - ETA: 0s - loss: 0.0066
# Epoch 00080: val_loss did not improve from 0.00526
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0065 - val_loss: 0.0053
# Epoch 81/100
# 1486/1489 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 00081: val_loss did not improve from 0.00526
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0067 - val_loss: 0.0053
# Epoch 82/100
# 1473/1489 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 00082: val_loss did not improve from 0.00526
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0067 - val_loss: 0.0054
# Epoch 83/100
# 1472/1489 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 00083: val_loss did not improve from 0.00526
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0064 - val_loss: 0.0053
# Epoch 84/100
# 1477/1489 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 00084: val_loss did not improve from 0.00526
# 1489/1489 [==============================] - 5s 3ms/step - loss: 0.0065 - val_loss: 0.0056

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss)+1)
plt.figure()
plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('Training and Valdation loss')
plt.legend()
plt.show()

# %%
# 예측
pred = model.predict(test_feature)

plt.figure(figsize=(12, 9))
plt.plot(test_label, label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mae = mean_absolute_error(test_label, pred)
mse = mean_squared_error(test_label, pred)
rmse = np.sqrt(mse)

# %%
predict_score = []
predict_score = pd.DataFrame(predict_score, columns = ['MAE','MSE','RMSE'])

# %%
predict_score = pd.DataFrame(data=[[mae,mse,rmse]], columns=['MAE','MSE','RMSE'])

# %%
predict_score
# Out:
#         MAE       MSE      RMSE
# 0  0.132823  0.026385  0.162435
